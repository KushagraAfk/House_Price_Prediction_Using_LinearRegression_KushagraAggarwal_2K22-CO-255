# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
test = pd.read_csv('test.csv')

# %%
train = pd.read_csv('train.csv')

# %%
train.head()
# Out:
#    ID     crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0   1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1   2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2   4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 3   5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# 4   7  0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311
#
#    ptratio   black  lstat  medv
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     18.7  394.63   2.94  33.4
# 3     18.7  396.90   5.33  36.2
# 4     15.2  395.60  12.43  22.9

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 333 entries, 0 to 332
# Data columns (total 15 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   ID       333 non-null    int64
#  1   crim     333 non-null    float64
#  2   zn       333 non-null    float64
#  3   indus    333 non-null    float64
#  4   chas     333 non-null    int64
#  5   nox      333 non-null    float64
#  6   rm       333 non-null    float64
#  7   age      333 non-null    float64
#  8   dis      333 non-null    float64
#  9   rad      333 non-null    int64
#  10  tax      333 non-null    int64
#  11  ptratio  333 non-null    float64
#  12  black    333 non-null    float64
#  13  lstat    333 non-null    float64
#  14  medv     333 non-null    float64
# dtypes: float64(11), int64(4)
# memory usage: 39.2 KB

# %%
test.drop(columns = ['ID'],inplace = True)

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173 entries, 0 to 172
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     173 non-null    float64
#  1   zn       173 non-null    float64
#  2   indus    173 non-null    float64
#  3   chas     173 non-null    int64
#  4   nox      173 non-null    float64
#  5   rm       173 non-null    float64
#  6   age      173 non-null    float64
#  7   dis      173 non-null    float64
#  8   rad      173 non-null    int64
#  9   tax      173 non-null    int64
#  10  ptratio  173 non-null    float64
#  11  black    173 non-null    float64
#  12  lstat    173 non-null    float64
# dtypes: float64(10), int64(3)
# memory usage: 17.7 KB

# %%
train.drop(columns = ['ID'], inplace = True)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 333 entries, 0 to 332
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     333 non-null    float64
#  1   zn       333 non-null    float64
#  2   indus    333 non-null    float64
#  3   chas     333 non-null    int64
#  4   nox      333 non-null    float64
#  5   rm       333 non-null    float64
#  6   age      333 non-null    float64
#  7   dis      333 non-null    float64
#  8   rad      333 non-null    int64
#  9   tax      333 non-null    int64
#  10  ptratio  333 non-null    float64
#  11  black    333 non-null    float64
#  12  lstat    333 non-null    float64
#  13  medv     333 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 36.6 KB

# %%
train['crim'].plot(kind = 'kde')
test['crim'].plot(kind = 'kde')
plt.legend(['train','test'])

# %%
train['zn'].plot(kind = 'kde')
test['zn'].plot(kind = 'kde')
plt.legend(['train','test'])

# %%
train['indus'].plot(kind = 'kde')
test['indus'].plot(kind = 'kde')
plt.legend(['train','test'])

# %%
train['chas'].plot(kind = 'kde')
test['chas'].plot(kind = 'kde')
plt.legend(['train','test'])

# %%
train['nox'].plot(kind = 'kde')
test['nox'].plot(kind = 'kde')
plt.legend(['train','test'])

# %%
train['rm'].plot(kind = 'kde')
test['rm'].plot(kind = 'kde')
plt.legend(['train','test'])

# %%
train['age'].plot(kind = 'kde')
test['age'].plot(kind = 'kde')
plt.legend(['train','test'])

# %%
train['dis'].plot(kind = 'kde')
test['dis'].plot(kind = 'kde')
plt.legend(['train','test'])

# %%
train['rad'].plot(kind = 'kde')
test['rad'].plot(kind = 'kde')
plt.legend(['train','test'])

# %%
train['rad'].value_counts()
# Out:
# rad
# 24    88
# 5     76
# 4     70
# 3     27
# 8     18
# 1     14
# 2     14
# 6     13
# 7     13
# Name: count, dtype: int64

# %%
train['tax'].plot(kind = 'kde')
test['tax'].plot(kind = 'kde')
plt.legend(['train','test'])

# %%
train['tax'].value_counts()
# Out:
# tax
# 666    88
# 307    27
# 403    21
# 437    10
# 398     9
# 304     9
# 296     8
# 224     8
# 264     8
# 384     8
# 233     7
# 330     7
# 188     6
# 193     6
# 432     6
# 277     6
# 284     5
# 222     5
# 270     5
# 329     4
# 287     4
# 711     4
# 300     4
# 273     4
# 311     4
# 216     4
# 247     4
# 223     3
# 281     3
# 305     3
# 391     3
# 243     3
# 289     3
# 276     2
# 370     2
# 430     2
# 252     2
# 245     2
# 265     2
# 345     2
# 337     2
# 254     1
# 198     1
# 242     1
# 279     1
# 411     1
# 335     1
# 280     1
# 351     1
# 422     1
# 402     1
# 348     1
# 256     1
# 313     1
# 226     1
# 293     1
# 241     1
# 469     1
# 285     1
# Name: count, dtype: int64

# %%
train['ptratio'].plot(kind = 'kde')
test['ptratio'].plot(kind = 'kde')
plt.legend(['train','test'])

# %%
train['black'].plot(kind = 'kde')
test['black'].plot(kind = 'kde')
plt.legend(['train','test'])

# %%
train['lstat'].plot(kind = 'kde')
test['lstat'].plot(kind = 'kde')
plt.legend(['train','test'])

# %%
train['medv'].plot(kind = 'kde')
# Out:
# <Axes: ylabel='Density'>

# %%
import seaborn as sns

# %%
sns.heatmap(train.corr())
# Out:
# <Axes: >

# %%
train.corr()['medv']
# Out:
# crim      -0.407454
# zn         0.344842
# indus     -0.473932
# chas       0.204390
# nox       -0.413054
# rm         0.689598
# age       -0.358888
# dis        0.249422
# rad       -0.352251
# tax       -0.448078
# ptratio   -0.481376
# black      0.336660
# lstat     -0.738600
# medv       1.000000
# Name: medv, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
reg.fit(train.drop(columns = ['medv']), train['medv'])
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([-5.24893379e-02,  4.74448677e-02,  5.38552422e-02,  3.78486439e+00,
#        -1.57396571e+01,  3.76883175e+00, -4.62660241e-03, -1.54882312e+00,
#         3.28967093e-01, -1.28664959e-02, -8.56975746e-01,  1.16659048e-02,
#        -6.00315456e-01])

# %%
reg.intercept_
# Out:
# 34.04543776350573

# %%
pred = reg.predict(test)

# %%
plt.hist(pred,bins = 20)
# Out:
# (array([ 1.,  1.,  3.,  6.,  1., 10.,  9., 15., 22., 27., 18., 10., 13.,
#          7.,  5.,  8., 10.,  2.,  3.,  2.]),
#  array([ 0.92727525,  3.04015629,  5.15303733,  7.26591837,  9.37879941,
#         11.49168045, 13.60456149, 15.71744253, 17.83032357, 19.94320461,
#         22.05608565, 24.16896669, 26.28184773, 28.39472877, 30.50760981,
#         32.62049086, 34.7333719 , 36.84625294, 38.95913398, 41.07201502,
#         43.18489606]),
#  <BarContainer object of 20 artists>)

# %%
preddf = pd.DataFrame(pred, columns = ['medv'])

# %%
preddf
# Out:
#           medv
# 0    30.599594
# 1    25.100459
# 2    18.158993
# 3     9.303476
# 4    17.689729
# ..         ...
# 168  16.763294
# 169  13.415179
# 170  21.361446
# 171  20.341302
# 172  26.675488
#
# [173 rows x 1 columns]

# %%
preddf.plot(kind = 'kde')
train['medv'].plot(kind = 'kde')
plt.legend(['test prediction prob density','train values prob density'])
plt.xlabel('medv')
# Out:
# Text(0.5, 0, 'medv')
